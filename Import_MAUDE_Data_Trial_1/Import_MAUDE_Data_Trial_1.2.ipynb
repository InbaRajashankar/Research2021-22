# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_pickle("./df2.pkl")

# %%
data.head(6)
# Out:
#   MDR_REPORT_KEY EVENT_KEY          REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0        6298948       NaN  3009498591-2016-00673                  M
# 1        6298948       NaN  3009498591-2016-00673                  M
# 2        7982437       NaN     2031009-2018-00026                  M
# 3        9537111       NaN  3001617766-2019-06390                  M
# 4        9537112       NaN     2134265-2019-16297                  M
# 5        9537112       NaN     2134265-2019-16297                  M
#
#   MANUFACTURER_LINK_FLAG_ NUMBER_DEVICES_IN_EVENT NUMBER_PATIENTS_IN_EVENT  \
# 0                       Y                     NaN                      NaN
# 1                       Y                     NaN                      NaN
# 2                       Y                     NaN                      NaN
# 3                       Y                     NaN                      NaN
# 4                       Y                     NaN                      NaN
# ...

# %%
data.shape
# Out:
# (3036606, 114)

# %%
for text in data.head(100)['FOI_TEXT']:
    print(text)
    print("\n")
# Out:
# THIS REPORT IS RESUBMITTED ON REQUEST BY THE FDA TO CORRECT FIELD TO INITIAL REPORT.
#
#
# PREVIOUSLY SUBMITTED.
#
#
# ON (B)(6) 2018 IT WAS REPORTED TO TRIMED THAT THERE WAS A INCIDENT OF INFECTION RELATED TO A SURGERY THAT INVOLVED THE TRIMED NITINOL STAPLE. ON (B)(6) TRIMED WAS GIVEN MORE INFORMATION ON THE INCIDENT, AND THAT THERE WERE SEVEN STAPLES INVOLVED IN THE ONE INCIDENT OF INFECTION. THERE WERE A TOTAL OF SEVEN STAPLES INVOLVED FROM LOTS 317003 (QUANTITY 3) AND LOT 317004 (QUANTITY 4). THIS INCIDENT WAS DISCOVERED AT (B)(6) HOSPITAL IN (B)(6). AN ACTIVE INFECTION WAS DISCOVERED NEAR THE SURGICAL SITE WITHIN THE FIRST POST-OPERATIVE WEEK. THIS IS THE FIRST TIME THIS TYPE OF INCIDENT HAS BEEN REPORTED TO TRIMED WITH THE CONCOMITANT USE OF THE NITINOL STAPLE.
#
#
# PER COMPLAINT (B)(4), AFTER CLINICAL PROCEDURE, PATIENT EXPERIENCED FAILURE OF IMPLANT TO OSSEOINTEGRATE.
#
#
# DATE OF EVENT: USED (B)(6) 2019 AS THE CORRECT DATE WAS NOT PROVIDED.
#
#
# ...

# %%
for text in data[data["MDR_REPORT_KEY"]=="6298948"]['FOI_TEXT']:
    print(text)
    print("\n")
# Out:
# THIS REPORT IS RESUBMITTED ON REQUEST BY THE FDA TO CORRECT FIELD TO INITIAL REPORT.
#
#
# PREVIOUSLY SUBMITTED.
