# %%
import numpy as np
import pandas as pd
import sys
import csv

csv.field_size_limit(1000000000000000000)
# Out:
# 131072

# %%
master1 = pd.read_csv('mdrfoiThru2020 copy.txt', sep="|", header = 0, dtype=str, engine='python')

# %%
master1
# Out:
#    MDR_REPORT_KEY EVENT_KEY REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0              10       NaN            10                  U
# 1              11       NaN            11                  U
# 2              12       NaN            12                  U
# 3              13       NaN            13                  U
# 4              14       NaN            14                  U
# 5              15       NaN            15                  U
# 6              16       NaN            16                  U
# 7              17       NaN            17                  U
# 8              19       NaN            19                  U
# 9              20       NaN            20                  U
# 10             21       NaN            21                  U
# 11             22       NaN            22                  U
# 12             23       NaN            23                  U
# 13             24       NaN            24                  U
#
# ...

# %%
master1[master1['MDR_REPORT_KEY']=='10']
# Out:
#   MDR_REPORT_KEY EVENT_KEY REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0             10       NaN            10                  U
#
#   MANUFACTURER_LINK_FLAG_ NUMBER_DEVICES_IN_EVENT NUMBER_PATIENTS_IN_EVENT  \
# 0                       N                     NaN                      NaN
#
#   DATE_RECEIVED ADVERSE_EVENT_FLAG PRODUCT_PROBLEM_FLAG  ...  \
# 0    03/10/1992                  Y                    N  ...
#
#   MANUFACTURER_COUNTRY_CODE MANUFACTURER_POSTAL_CODE TYPE_OF_REPORT  \
# 0                       NaN                      NaN              I
#
#   SOURCE_TYPE  DATE_ADDED DATE_CHANGED REPORTER_COUNTRY_CODE PMA_PMN_NUM  \
# 0         NaN  03/19/1992   06/23/2020                   NaN         NaN
#
#   EXEMPTION_NUMBER SUMMARY_REPORT
# 0              NaN              N
#
# [1 rows x 81 columns]

# %%
master = pd.read_csv('mdrfoiThru2020.txt', sep="|", header = 0, dtype=str, engine='python', quoting=3)
master1 = pd.read_csv('mdrfoiThru2020 copy.txt', sep="|", header = 0, dtype=str, engine='python')

# %%
master.head(10)
# Out:
#   MDR_REPORT_KEY EVENT_KEY REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0             10       NaN            10                  U
# 1             11       NaN            11                  U
# 2             12       NaN            12                  U
# 3             13       NaN            13                  U
# 4             14       NaN            14                  U
# 5             15       NaN            15                  U
# 6             16       NaN            16                  U
# 7             17       NaN            17                  U
# 8             19       NaN            19                  U
# 9             20       NaN            20                  U
#
#   MANUFACTURER_LINK_FLAG_ NUMBER_DEVICES_IN_EVENT NUMBER_PATIENTS_IN_EVENT  \
# 0                       N                     NaN                      NaN
# 1                       N                     NaN                      NaN
# 2                       N                     NaN                      NaN
# ...

# %%
master[master['MDR_REPORT_KEY'] == '6298948']
# Out:
#         MDR_REPORT_KEY EVENT_KEY          REPORT_NUMBER REPORT_SOURCE_CODE  \
# 6004830        6298948       NaN  3009498591-2016-00673                  M
#
#         MANUFACTURER_LINK_FLAG_ NUMBER_DEVICES_IN_EVENT  \
# 6004830                       Y                     NaN
#
#         NUMBER_PATIENTS_IN_EVENT DATE_RECEIVED ADVERSE_EVENT_FLAG  \
# 6004830                      NaN    04/16/2020                  N
#
#         PRODUCT_PROBLEM_FLAG  ... MANUFACTURER_COUNTRY_CODE  \
# 6004830                    N  ...                       NaN
#
#         MANUFACTURER_POSTAL_CODE TYPE_OF_REPORT SOURCE_TYPE  DATE_ADDED  \
# 6004830                      NaN              I         NaN  02/02/2017
#
#         DATE_CHANGED REPORTER_COUNTRY_CODE PMA_PMN_NUM EXEMPTION_NUMBER  \
# 6004830   05/20/2020                   NaN         NaN              NaN
#
#         SUMMARY_REPORT
# 6004830              N
#
# [1 rows x 81 columns]

# %%
master.shape
# Out:
# (10800979, 81)

# %%
for col in master.columns:
    print(col)
# Out:
# MDR_REPORT_KEY
# EVENT_KEY
# REPORT_NUMBER
# REPORT_SOURCE_CODE
# MANUFACTURER_LINK_FLAG_
# NUMBER_DEVICES_IN_EVENT
# NUMBER_PATIENTS_IN_EVENT
# DATE_RECEIVED
# ADVERSE_EVENT_FLAG
# PRODUCT_PROBLEM_FLAG
# DATE_REPORT
# DATE_OF_EVENT
# REPROCESSED_AND_REUSED_FLAG
# REPORTER_OCCUPATION_CODE
# HEALTH_PROFESSIONAL
# INITIAL_REPORT_TO_FDA
# DATE_FACILITY_AWARE
# REPORT_DATE
# REPORT_TO_FDA
# DATE_REPORT_TO_FDA
# EVENT_LOCATION
# DATE_REPORT_TO_MANUFACTURER
# MANUFACTURER_CONTACT_T_NAME
# MANUFACTURER_CONTACT_F_NAME
# MANUFACTURER_CONTACT_L_NAME
# MANUFACTURER_CONTACT_STREET_1
# MANUFACTURER_CONTACT_STREET_2
# MANUFACTURER_CONTACT_CITY
# MANUFACTURER_CONTACT_STATE
# MANUFACTURER_CONTACT_ZIP_CODE
# MANUFACTURER_CONTACT_ZIP_EXT
# MANUFACTURER_CONTACT_COUNTRY
# MANUFACTURER_CONTACT_POSTAL
# MANUFACTURER_CONTACT_AREA_CODE
# MANUFACTURER_CONTACT_EXCHANGE
# MANUFACTURER_CONTACT_PHONE_NO
# MANUFACTURER_CONTACT_EXTENSION
# MANUFACTURER_CONTACT_PCOUNTRY
# MANUFACTURER_CONTACT_PCITY
# ...

# %%
device1 = pd.read_csv('DEVICE2020 copy.txt', sep="|", header = 0, dtype=str, engine='python', quoting=3)

# %%
device1
# Out:
#     MDR_REPORT_KEY DEVICE_EVENT_KEY IMPLANT_FLAG DATE_REMOVED_FLAG  \
# 0          6298948              NaN          NaN               NaN
# 1          7982437              NaN          NaN               NaN
# 2          9537111              NaN          NaN               NaN
# 3          9537112              NaN          NaN               NaN
# 4          9537113              NaN          NaN               NaN
# ..             ...              ...          ...               ...
# 110        9537219              NaN          NaN               NaN
# 111        9537220              NaN          NaN               NaN
# 112        9537221              NaN          NaN               NaN
# 113        9537222              NaN          NaN               NaN
# 114        9537223              NaN          NaN               NaN
#
#     DEVICE_SEQUENCE_NO DATE_RECEIVED               BRAND_NAME  \
# 0                    1    2020/04/16                      NaN
# ...

# %%
master.to_pickle("./master.pkl")

# %%
master2 = pd.read_pickle("./master.pkl")

# %%
master2.head()
# Out:
#   MDR_REPORT_KEY EVENT_KEY REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0             10       NaN            10                  U
# 1             11       NaN            11                  U
# 2             12       NaN            12                  U
# 3             13       NaN            13                  U
# 4             14       NaN            14                  U
#
#   MANUFACTURER_LINK_FLAG_ NUMBER_DEVICES_IN_EVENT NUMBER_PATIENTS_IN_EVENT  \
# 0                       N                     NaN                      NaN
# 1                       N                     NaN                      NaN
# 2                       N                     NaN                      NaN
# 3                       N                     NaN                      NaN
# 4                       N                     NaN                      NaN
#
#   DATE_RECEIVED ADVERSE_EVENT_FLAG PRODUCT_PROBLEM_FLAG  ...  \
# 0    03/10/1992                  Y                    N  ...
# ...

# %%
pd.merge(master2, device1, on="MDR_REPORT_KEY")
# Out:
#     MDR_REPORT_KEY EVENT_KEY          REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0          6298948       NaN  3009498591-2016-00673                  M
# 1          7982437       NaN     2031009-2018-00026                  M
# 2          9537111       NaN  3001617766-2019-06390                  M
# 3          9537112       NaN     2134265-2019-16297                  M
# 4          9537113       NaN     2134265-2019-16283                  M
# ..             ...       ...                    ...                ...
# 110        9537219       NaN  3004604967-2020-00002                  M
# 111        9537220       NaN  3007573469-2020-00002                  D
# 112        9537221       NaN     8030665-2020-00002                  M
# 113        9537222       NaN  3004209178-2020-00002                  M
# 114        9537223       NaN     2938836-2019-17570                  M
#
#     MANUFACTURER_LINK_FLAG_ NUMBER_DEVICES_IN_EVENT NUMBER_PATIENTS_IN_EVENT  \
# ...

# %%
device = pd.read_csv('DEVICE2020.txt', sep="|", header = 0, dtype=str, engine='python', quoting=3)

# %%
text = pd.read_csv('foitext2020.txt', sep="|", header = 0, dtype=str, engine='python', quoting=3)

# %%
device.to_pickle("./device.pkl")
text.to_pickle("./text.pkl")

# %%
device.head(10)
# Out:
#   MDR_REPORT_KEY DEVICE_EVENT_KEY IMPLANT_FLAG DATE_REMOVED_FLAG  \
# 0        6298948              NaN          NaN               NaN
# 1        7982437              NaN          NaN               NaN
# 2        9537111              NaN          NaN               NaN
# 3        9537112              NaN          NaN               NaN
# 4        9537113              NaN          NaN               NaN
# 5        9537114              NaN          NaN               NaN
# 6        9537115              NaN          NaN               NaN
# 7        9537116              NaN          NaN               NaN
# 8        9537117              NaN          NaN               NaN
# 9        9537118              NaN          NaN               NaN
#
#   DEVICE_SEQUENCE_NO DATE_RECEIVED  \
# 0                  1    2020/04/16
# 1                  1    2020/07/10
# 2                  1    2020/01/01
# 3                  1    2020/01/01
# 4                  1    2020/01/01
# ...

# %%
text.head(10)
# Out:
#   MDR_REPORT_KEY MDR_TEXT_KEY TEXT_TYPE_CODE PATIENT_SEQUENCE_NUMBER  \
# 0        9537171    173269159              N                       1
# 1        9537171    173269160              D                       1
# 2        9537125    173269515              N                       1
# 3        9537125    173269516              D                       1
# 4        9537119    173269518              N                       1
# 5        9537119    173269519              D                       1
# 6        9537209    173269527              N                       1
# 7        9537209    173269528              D                       1
# 8        9537210    173269533              N                       1
# 9        9537210    173269534              D                       1
#
#   DATE_REPORT                                           FOI_TEXT
# 0         NaN  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1         NaN  IT WAS REPORTED THAT THE PATIENT EXPIRED. THER...
# ...

# %%
df1 = pd.merge(master, device, on="MDR_REPORT_KEY")

# %%
df2 = pd.merge(df1, text, on='MDR_REPORT_KEY')

# %%
df1.shape
# Out:
# (1567307, 109)

# %%
df2.to_pickle("./df2.pkl")

# %%
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68302b2f4bd0> in <module>
# ----> 1 df2.head()
#
# NameError: name 'df2' is not defined
